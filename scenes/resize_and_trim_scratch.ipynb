# %%
# %matplotlib inline
import numpy as np
import os

import numpy as np
import matplotlib.pyplot as plt

import time
import scipy
from scipy.misc import imread
from scipy.misc import imresize
from scipy import fftpack
import glob
import cv2

# %%
img_folder = '/Users/cesar/Documents/CoxLab/Repos/scene_stimuli/Original'

# %%
img_list = glob.glob(os.path.join(img_folder,'*'))

# %%
im0 = imread(img_list[50])
im0 = np.mean(im0,2).squeeze()

# %%
print(im0.shape)
plt.imshow(im0)
# Out:
# (375, 500)

# %%
szy,szx = im0.shape
resize_factor = np.floor(szx/192)
print(resize_factor)
# Out:
# 2.0

# %%
im1 = cv2.pyrDown(im0,(szx/resize_factor,szy/resize_factor))

# %%
print(im1.shape)
plt.imshow(im1)
# Out:
# (188, 250)

# %%
szy,szx = im1.shape
#if (szx%2 ==1):
excessx = int((szx-128)/2)
x0 = excessx
x1 = excessx+256
im2 = im1[:,x0:x1]
# Out:
# 500

# %%
img_list = glob.glob(os.path.join(img_folder,'*'))

# %%
im0 = imread(img_list[0])
im0 = np.mean(im0,2).squeeze()

# %%
print(im0.shape)
plt.imshow(im0)
# Out:
# (375, 500)

# %%
szy,szx = im0.shape
resize_factor = 256/szy

im1 = imresize(im0,resize_factor)

# %%
print(im1.shape)
plt.imshow(im1)
# Out:
# (256, 341)

# %%
szy,szx = im1.shape
#if (szx%2 ==1):
    excessx = int((szx-256)/2)
    x0 = excessx
    x1 = excessx+256
    im2 = im1[:,x0:x1]

# %%
print(im2.shape)
plt.imshow(im2)
# Out:
# (256, 256)

# %%
plt.imshow(im2[56:200,:])

# %%
128-72
# Out:
# 56

# %%
img_folder = '/Users/cesar/Documents/CoxLab/stimuli/lowPass'
img_fn = '3.tif'

# %%
#want 256x448

# %%
768-1080
# Out:
# -312

# %%
1920-1024
# Out:
# 896

# %%
896/2
# Out:
# 448.0

# %%
print(im0.shape)
plt.imshow(im0)
# Out:
# (768, 1024)

# %%
im2 = np.pad(im0,((156,156),(448,448)),'constant')

# %%
plt.imshow(im2)

# %%
im1= imresize(im0,((256,341)))

# %%
plt.imshow(im1)

# %%
scipy.misc.imsave('tmp.png',im1)

# %%
#256x455
